# %% [markdown]
# Запрос "sweet red wine"

# %%
# !python main.py --query "sweet red wine" --mode bm25
# Out:
# Search [bm25] took: 0.7981 seconds
#                                                   title                                        description
# 9319  Pradorey 2011 Rosado Joven Tempranillo Rosé (R...  Red in color, with sweet aromas of sugar beet,...
# 1496  Pomar Junction 2010 Brooster Fighting Red Red ...  Too soft in structure, and sweet, too, like be...
# 4596  Domaine Anne Gros 2006 Les Barreaux  (Vosne-Ro...  With its wonderful, heady aromas of red fruits...
# 5345  Federico Paternina 2008 Marqués de Valparaiso ...  The nose on this wine smells candied for the m...
# 4681  Domaine Berthet-Bondet 2008 Vin de Paille Whit...  This wine has a mix of honey, sweet cherry fru...

# %%
# !python main.py --query "sweet red wine" --mode word2vec
# Out:
# Search [word2vec] took: 2.6476 seconds
#                                                   title                                        description
# 6874         Falesco 2009 Pomele 500ml Aleatico (Lazio)  Pomele is a sweet red wine made from the Aleat...
# 1795             Quinta de Lemos 2010 Alfrocheiro (Dão)  This is an aromatic wine, one of a series of f...
# 5609  Ollivier Frères 2015 Domaine de la Grenaudière...  An attractive, fruity wine that is soft and sm...
# 1496  Pomar Junction 2010 Brooster Fighting Red Red ...  Too soft in structure, and sweet, too, like be...
# 7961  L. Tramier & Fils 2015 Collection Premier Cru ...  The wine is soft, fruity and immediately acces...

# %%
# !python main.py --query "sweet red wine" --mode fasttext
# Out:
# Search [fasttext] took: 1.4776 seconds
#                                                   title                                        description
# 1795             Quinta de Lemos 2010 Alfrocheiro (Dão)  This is an aromatic wine, one of a series of f...
# 6874         Falesco 2009 Pomele 500ml Aleatico (Lazio)  Pomele is a sweet red wine made from the Aleat...
# 4205  Georges Vigouroux 2014 Gouleyant Rosé (Côtes d...  This 100% Malbec rosé comes from vineyards in ...
# 5524      Domaine Chandon 2011 Pinot Meunier (Carneros)  Almost indistinguishable from a Pinot Noir, th...
# 5192  Baron-Fuenté NV Esprit Rosé de Saignée  (Champ...  Darker in color than many rosés, this Champagn...

# %% [markdown]
# Запрос "fruity red berry"

# %%
# !python main.py --query "fruity berry" --mode bm25
# Out:
# Search [bm25] took: 0.7995 seconds
#                                                   title                                        description
# 9719  Château la Croix Saint-Pierre 2010  Blaye Côte...  Almost too fruity, the wine has red berry frui...
# 7413  Quinta da Lagoalva de Cima 2012 Espirito Rosé ...  An intensely fruity rosé, the palate is full w...
# 6512  Domaine Pral 2014 Les Pays de Pierres Dorées  ...  Banana aromas don't intrude too strongly into ...
# 8314  Wines & Winemakers 2011 Azul Portugal Rosé (Se...  Ripe and fruity, this bears a red berry flavor...
# 2247                  Sanguinhal 2010 Aragonez (Lisboa)  This fruity, jammy and ripe wine is full of bl...

# %%
# !python main.py --query "fruity berry" --mode word2vec
# Out:
# Search [word2vec] took: 2.6057 seconds
#                                                   title                                        description
# 3427         Roncolato 2005  Amarone della Valpolicella  This is a jammy, mature Amarone that imparts a...
# 4534       Cola NV Athena Rosé Sparkling (Franciacorta)  This rosé opens with a floral and fruity fragr...
# 6754       Domaine Collotte 2014 Combereau  (Marsannay)  This is a juicy, fruity wine with intense acid...
# 5022  Gia Domella 2006 E. Passalacqua Heritage Estat...  Hot in alcohol and sweet in ripe fruit and gly...
# 7514  A. de Luze et Fils 2015 Fleur de Sauvignon  (B...  This aromatic herbal Sauvignon is crisp while ...

# %%
# !python main.py --query "fruity berry" --mode fasttext
# Out:
# Search [fasttext] took: 1.4966 seconds
#                                                   title                                        description
# 6754       Domaine Collotte 2014 Combereau  (Marsannay)  This is a juicy, fruity wine with intense acid...
# 7514  A. de Luze et Fils 2015 Fleur de Sauvignon  (B...  This aromatic herbal Sauvignon is crisp while ...
# 2127   Pine Ridge 2009 Cabernet Sauvignon (Napa Valley)  Ripe and fruity, this has an oak flavor that o...
# 5886  SignoSeis 2013 The Angel Oak Malbec (Valle de ...  Reedy aromas of olive, leather and oak are les...
# 2570  Rutherford Hill 2008 Reserve Merlot (Napa Valley)  Dry and classy, this is tart in acidity, with ...

# %% [markdown]
# Запрос "cabernet sauvignon"

# %%
# !python main.py --query "cabernet sauvignon" --mode bm25
# Out:
# Search [bm25] took: 0.8007 seconds
#                                                   title                                        description
# 4940  Envolve 2010 Puma Springs Vineyard Red (Dry Cr...  Rustic and dry, this has flavors of berries, c...
# 9157  Pondera 2011 SVS Number One Conner Lee Vineyar...  This blend of Cabernet Sauvignon, Merlot, Cabe...
# 5338  Fielding Hills 2010 Tribute RiverBend Vineyard...  A blend of Cabernet Franc, Syrah, Merlot, and ...
# 7267    Ste. Chapelle 2011 Treasure Valley Reserves Red  A blend of Cabernet Sauvignon, Merlot, Syrah a...
# 2623  B.R. Cohn 2009 Silver Label Cabernet Sauvignon...  Medium-bodied and easy drinking, this Cabernet...

# %%
# !python main.py --query "cabernet sauvignon" --mode word2vec
# Out:
# Search [word2vec] took: 2.6020 seconds
#                                                   title                                        description
# 4205  Georges Vigouroux 2014 Gouleyant Rosé (Côtes d...  This 100% Malbec rosé comes from vineyards in ...
# 4155                  Kestrel 2006 Rosé (Yakima Valley)  Nice spice and strawberry fruit. The blend is ...
# 7675  Columbia Crest 2012 Grand Estates Red (Columbi...  This wine is 57% Syrah, 25% Cabernet Sauvignon...
# 6715          Vigilance 2010 Cimarron Red (Lake County)  Ripe and broad shouldered, this blend of Zinfa...
# 7402                   Open Range 2008 Red (California)  This is comprised of 55% Cabernet Sauvignon, 3...

# %%
# !python main.py --query "cabernet sauvignon" --mode fasttext
# Out:
# Search [fasttext] took: 1.4627 seconds
#                                                   title                                        description
# 6715          Vigilance 2010 Cimarron Red (Lake County)  Ripe and broad shouldered, this blend of Zinfa...
# 9777   Krupp Brothers 2006 The Doctor Red (Napa Valley)  Napa red wine hardly gets more delicious than ...
# 4692  Viszlay Vineyards 2012 Five Vines Red (Russian...  This wine is made from a majority Merlot, with...
# 5338  Fielding Hills 2010 Tribute RiverBend Vineyard...  A blend of Cabernet Franc, Syrah, Merlot, and ...
# 880   Northstar 2012 Stella Maris Red (Columbia Vall...  This wine is predominantly Merlot and Cabernet...
